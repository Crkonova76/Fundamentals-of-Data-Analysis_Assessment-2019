# %% [markdown]
# # Tips Dataset
#
# ## Definition
#
# The main reason for collecting data for Tips dataset was to analyse the factors influencing the food server's tips in restaurant. The collection of data was conducted in one restaurant,by one person, located in a suburban shopping centre during an interval of two and a half months in early 1990. All collected data represents the collector's work schedule.
#
# The following categories of data were assembled on all food served customers:
#
# * Total bill (cost of the meal)including tax, in US dollars
# * Tip in US dollars
# * Sex of the person paying for the meal
# * Is smoker in party?
# * Day of the week
# * Time of the day
# * Size of the party

# %% [markdown]
# ## 1, Descriptive analysis of the dataset

# %% [markdown]
# To import various libraries as numpy, seaborn (plotting), pandas

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# To upload the file from the url address and create the dataframe using Pandas

# %%
df=pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# A data frame with 244 rows and 7 variables

# %% [markdown]
# _Dataset has 244 rows and 7 columns. By checking the last 5 lines we can see if  all data are showing correctly:_

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# _To inspect the type of data in the columns._

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %% [markdown]
# _To visualise relationships of variables: tip, total_bill and size the scatter plots are used, histograms visualise the data distributions . The pairplot is special plot from seaborn,which creates a grid of axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.The diagonal axes draw a plot to show the univariate distribution of the data for the variable in that column._

# %% [markdown]
# * _source: https://seaborn.pydata.org/generated/seaborn.pairplot.html_

# %%
sns.pairplot(df)

# %% [markdown]
# _The basic statistics can be called by __. describe()__ function:_

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# The describe() function provides the calculation of mean, standard deviation, minimal, maximal value and median (50%). The sample contains 244 lines of records, which consist of different variables like total bill,tip paid, sex of the paying person, if the smoker was in the group, when the food was served (day and the time), the size of the group.
#
#
# In average USD19.79 was spent in total and in average USD1.38 of tips was paid. In average the group of 2-3 people visited the resturant during the period, when the sample was collected.
#
# There is the difference between median (50%) and mean of tips and total bill in Tips dataset, which indicates that the datasets is not completely symetric. The visualisation of distributions of data through the histograms in pairplot above or in the histograms below reveal that the distribution is actually right skewed.Right skewer distributions means that median is lower value than mean. The median is considered to better represents for the central locations of data then mean.
#
# Standard deviation shows how the data are distributed in the dataset. Basically, a small standard deviation means that the values in a statistical data set are close to the mean of the data set, on average, and a large standard deviation means that the values in the data set are farther away from the mean, on average. The smallest standard deviations is in the variable size, which proofs that majority of visits was group of two and tree customers.

# %% [markdown]
# In order to be able to compare the above calculated figures with sub groups figures of same calculation, the pivot tables can be generated.
#
# * _souce:https://pbpython.com/pandas-pivot-table-explained.html_

# %% [markdown]
# _Histogram can be used to visualise the distribution of one variable._

# %%
sns.distplot(df['tip'], kde=False, bins=10)

# %%
sns.distplot(df['total_bill'], kde=False, bins=10)

# %% [markdown]
# Both histograms have the bell shaped curve, right-skewed. The mean of right-skewed data will be located to the right side of the plot and will be a greater value than the median.

# %% [markdown]
# * _source:https://www.ck12.org/book/CK-12-Probability-and-Statistics-Concepts/section/4.6/_

# %% [markdown]
# ### Variable "SEX"

# %%
sns.pairplot(df,hue="sex")

# %% [markdown]
# _By this pivot table we are able to see the breakdown of how many female/male paid for dinner and lunch. We can see that in total 157 males paid for food comparing to 87 females (simplified second pivot table when only one index "sex" is used)._

# %%
pd.pivot_table(df, index=["time","sex"],aggfunc="size")
# Out:
# time    sex
# Dinner  Female     52
#         Male      124
# Lunch   Female     35
#         Male       33
# dtype: int64

# %%
pd.pivot_table(df, index=["sex"],aggfunc="size")
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %% [markdown]
# _The total count selected just on one column "sex"._

# %%
df.loc[:,"sex"].count()
# Out:
# 244

# %% [markdown]
# _The pivot table calculates the mean, max, min and standard deviation as per sex of person paying the bill._

# %%
pd.pivot_table(df, index=["sex"],aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#             mean                       amax                           \
#             size       tip total_bill   day size smoker   time   tip
# sex
# Female  2.459770  2.833448  18.056897  Thur    6    Yes  Lunch   6.5
# Male    2.630573  3.089618  20.744076  Thur    6    Yes  Lunch  10.0
#
#                   amin                                           std  \
#        total_bill  day size smoker    time  tip total_bill      size
# sex
# Female      44.30  Fri    1     No  Dinner  1.0       3.07  0.937644
# Male        50.81  Fri    1     No  Dinner  1.0       7.25  0.955997
#
#
#              tip total_bill
# sex
# Female  1.159495   8.009209
# Male    1.489102   9.246469

# %% [markdown]
# Based on the calculated figures we can expect that females paid in average lower value for food and less tips included to pay compared to men. The standard deviations calculated for tips and total bill is lower for values related to females, which might indicate that the values are closer to the mean(average) in female selection compared to men selection. The other variables for both sex selection are in line with each other. It might be intresting to investigate if tips compared to total bill paid by female are lower then the same just for men (investigated further in part 3).

# %% [markdown]
# _To visualise some of the findings about relating to the variable "sex" we use scatter plot, displaying females or males paying for dinner respectively lunch_

# %%
sns.set(style="ticks",palette="muted")
sns.relplot(x="total_bill", y="tip", col="time", hue="sex",data=df)

# %% [markdown]
# ### Variable "DAY"

# %%
sns.pairplot(df,hue="day")

# %% [markdown]
# _To describe the basic information about the variable day_

# %%
df["day"].describe()
# Out:
# count     244
# unique      4
# top       Sat
# freq       87
# Name: day, dtype: object

# %% [markdown]
# _To evaluate what day was mostly visited day by the paying customers._

# %%
pd.pivot_table(df, index=["day"],aggfunc="size")
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# dtype: int64

# %%
pd.pivot_table(df, index=["day"],aggfunc=[np.mean, np.min,np.max, np.std])
# Out:
#           mean                         amin                            \
#           size       tip total_bill     sex size smoker    time   tip
# day
# Fri   2.105263  2.734737  17.151579  Female    1     No  Dinner  1.00
# Sat   2.517241  2.993103  20.441379  Female    1     No  Dinner  1.00
# Sun   2.842105  3.255132  21.410000  Female    2     No  Dinner  1.01
# Thur  2.451613  2.771452  17.682742  Female    1     No  Dinner  1.25
#
#                  amax                                             std  \
#      total_bill   sex size smoker    time    tip total_bill      size
# day
# Fri        5.75  Male    4    Yes   Lunch   4.73      40.17  0.567131
# Sat        3.07  Male    5    Yes  Dinner  10.00      50.81  0.819275
# Sun        7.25  Male    6    Yes  Dinner   6.50      48.17  1.007341
# Thur       7.51  Male    6    Yes   Lunch   6.70      43.11  1.066285
#
#
#            tip total_bill
# day
# Fri   1.019577   8.302660
# Sat   1.631014   9.480419
# Sun   1.234880   8.832122
# Thur  1.240223   7.886170

# %% [markdown]
# The most paying customers visited the restaurant on Saturday, however the Sunday looks like a day when the customers are more generous. Average tip paid on Sunday is higher than on Saturday even when we look on maximum tip-paid on Saturday . The standard deviation suggest that on Sunday more customers pay around the average of tips. The tips paid on Friday and Thursday are below average of the value of tips.

# %% [markdown]
# adopted from source: https://seaborn.pydata.org/introduction.html

# %% [markdown]
# _The scatterplot evaluete the relationships between the tips and total bills break down by the day of the visit_

# %%
sns.set(style="ticks", palette="muted")
sns.relplot(x="total_bill", y="tip", 
            hue="day", style="day",
            data=df);

# %% [markdown]
# The plot above shows relationship between tips and total bills, differentiated by different days. We can read a positive reliatonship between observations.

# %% [markdown]
# _To visualise the range from the minimum and maximum tip paid on each of the day,displayed by the meal type. The median (50%) is displayed by the midle line in rectangulars_

# %%
g = sns.catplot(x="tip", y="day", hue="time",
                height=4.5, aspect=4.5,
                kind="box", legend=False, data=df);
g.add_legend(title="Meal")
g.set_axis_labels("Tip ($)", "")
g.set(xlim=(0, 10), yticklabels=["Thursday", "Friday", "Saturday", "Sunday"])
g.despine(trim=True)
g.fig.set_size_inches(10, 3.5)
g.ax.set_xticks([2, 4, 6, 8, 10, 12], minor=True);
plt.setp(g.ax.get_yticklabels(), rotation=30);

# %% [markdown]
# The plot evaluetes if the data appear to be skewed, so if the majority of data are located on the high or low side of the range. We can easily read from the graph, that on Saturday and Sunday dinner majority of customers paid higher tips as on other days (the median is located more to the lower value of the range).Outliers can strongly affect the results of the analysis. They are visible from the previous (scatter plot) in right top corner of the plot.

# %% [markdown]
# ### Variable "SMOKER"

# %% [markdown]
# _The pairplot used to demonstrate the visual side of dataset split by smoker_

# %%
sns.pairplot(df,hue="smoker")

# %% [markdown]
# _To see basic statistics used describe() function. Provides only the overview of the variable_

# %%
df["smoker"].describe()
# Out:
# count     244
# unique      2
# top        No
# freq      151
# Name: smoker, dtype: object

# %% [markdown]
# _Pivot table used to calculate the mean, min and max value and standard deviation of total bill and tips split by smoker/non-smoker._

# %%
pd.pivot_table(df,index=["smoker"],values=["tip","total_bill"], aggfunc=[np.mean, np.min,np.max,np.std])
# Out:
#             mean            amin             amax                  std  \
#              tip total_bill  tip total_bill   tip total_bill       tip
# smoker
# No      2.991854  19.188278  1.0       7.25   9.0      48.33  1.377190
# Yes     3.008710  20.756344  1.0       3.07  10.0      50.81  1.401468
#
#
#        total_bill
# smoker
# No       8.255582
# Yes      9.832154

# %% [markdown]
# _Two datasets created from df dataframe, one called "smoker"-contains only data if in the group was at least one smoker and "nosmok"-contains data selected on the group with no smokers._

# %%
smoker=df[df.loc[:,"smoker"]=="Yes"]

# %%
smoker
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2
# 63        18.29  3.76    Male    Yes   Sat  Dinner     4
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 95        40.17  4.73    Male    Yes   Fri  Dinner     4
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 105       15.36  1.64    Male    Yes   Sat  Dinner     2
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4
# 208       24.27  2.03    Male    Yes   Sat  Dinner     2
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
nosmok=df[df.loc[:,"smoker"]=="No"]

# %%
nosmok
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 150       14.07  2.50    Male     No   Sun  Dinner     2
# 151       13.13  2.00    Male     No   Sun  Dinner     2
# 152       17.26  2.74    Male     No   Sun  Dinner     3
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 154       19.77  2.00    Male     No   Sun  Dinner     4
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 157       25.00  3.75  Female     No   Sun  Dinner     4
# 158       13.39  2.61  Female     No   Sun  Dinner     2
# 159       16.49  2.00    Male     No   Sun  Dinner     4
# 160       21.50  3.50    Male     No   Sun  Dinner     4
# 161       12.66  2.50    Male     No   Sun  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 163       13.81  2.00    Male     No   Sun  Dinner     2
# 165       24.52  3.48    Male     No   Sun  Dinner     3
# 166       20.76  2.24    Male     No   Sun  Dinner     2
# 167       31.71  4.50    Male     No   Sun  Dinner     4
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %% [markdown]
# _To confirm that the dataframes are complete...Smokers count to 93, non smoker to 151...total 244 what is the full count of dataset df. Also the basic statistic provided by describe () function_

# %%
nosmok.describe()
# Out:
#        total_bill         tip        size
# count  151.000000  151.000000  151.000000
# mean    19.188278    2.991854    2.668874
# std      8.255582    1.377190    1.017984
# min      7.250000    1.000000    1.000000
# 25%     13.325000    2.000000    2.000000
# 50%     17.590000    2.740000    2.000000
# 75%     22.755000    3.505000    3.000000
# max     48.330000    9.000000    6.000000

# %%
smoker.describe()
# Out:
#        total_bill        tip       size
# count   93.000000  93.000000  93.000000
# mean    20.756344   3.008710   2.408602
# std      9.832154   1.401468   0.810751
# min      3.070000   1.000000   1.000000
# 25%     13.420000   2.000000   2.000000
# 50%     17.920000   3.000000   2.000000
# 75%     26.860000   3.680000   3.000000
# max     50.810000  10.000000   5.000000

# %% [markdown]
# _Pivot tables used to get the basic statistics as per sub groups_

# %%
pd.pivot_table(smoker,index=["time","day"],values=["tip","total_bill"], aggfunc=[np.mean, np.min,np.max,len])
# Out:
#                  mean             amin              amax              len  \
#                   tip total_bill   tip total_bill    tip total_bill   tip
# time   day
# Dinner Fri   3.003333  19.806667  1.00       5.75   4.73      40.17   9.0
#        Sat   2.875476  21.276667  1.00       3.07  10.00      50.81  42.0
#        Sun   3.516842  24.120000  1.50       7.25   6.50      45.35  19.0
# Lunch  Fri   2.280000  12.323333  1.58       8.58   3.48      16.27   6.0
#        Thur  3.030000  19.190588  2.00      10.34   5.00      43.11  17.0
#
#
#             total_bill
# time   day
# Dinner Fri         9.0
#        Sat        42.0
#        Sun        19.0
# Lunch  Fri         6.0
#        Thur       17.0

# %%
pd.pivot_table(nosmok,index=["time","day"],values=["tip","total_bill","size"], aggfunc=[np.mean, np.min,np.max,len])
# Out:
#                  mean                      amin                  amax       \
#                  size       tip total_bill size   tip total_bill size  tip
# time   day
# Dinner Fri   2.000000  2.750000  19.233333    2  1.50      12.46    2  3.5
#        Sat   2.555556  3.102889  19.661778    1  1.00       7.25    4  9.0
#        Sun   2.929825  3.167895  20.506667    2  1.01       8.77    6  6.0
#        Thur  2.000000  3.000000  18.780000    2  3.00      18.78    2  3.0
# Lunch  Fri   3.000000  3.000000  15.980000    3  3.00      15.98    3  3.0
#        Thur  2.500000  2.666364  17.075227    1  1.25       7.51    6  6.7
#
#                         len
#             total_bill size   tip total_bill
# time   day
# Dinner Fri       22.75    3   3.0        3.0
#        Sat       48.33   45  45.0       45.0
#        Sun       48.17   57  57.0       57.0
#        Thur      18.78    1   1.0        1.0
# Lunch  Fri       15.98    1   1.0        1.0
#        Thur      41.19   44  44.0       44.0

# %% [markdown]
# Group with smokers paid in average higher total bill and tips as the groups without the smokers. The range between the min and max tips is higher in group with smokers than the non smokers group. The standard deviation is higher in smoker group.

# %% [markdown]
# _Boxplots used to visualise the range, median of tips for group with or without smoker_

# %% [markdown]
# _Thirst two boxplots compare the smoker dataset on the variable total bill and tip, categorised by the variable "sex"._

# %%
sns.catplot(x="time", y="total_bill", hue="sex", kind="box", data=smoker)

# %%
sns.catplot(x="time", y="tip", hue="sex", kind="box", data=smoker)

# %%
pd.pivot_table(smoker,index=["time","sex"],values=["tip","total_bill"], aggfunc=[np.mean, np.median,len])
# Out:
#                    mean            median              len
#                     tip total_bill    tip total_bill   tip total_bill
# time   sex
# Dinner Female  2.949130  18.215652    3.0     16.320  23.0       23.0
#        Male    3.123191  23.642553    3.0     23.100  47.0       47.0
# Lunch  Female  2.891000  17.431000    2.5     14.845  10.0       10.0
#        Male    2.790769  17.374615    2.2     16.000  13.0       13.0

# %% [markdown]
# In smoker dataset the median of paid total bill is lower in the case if females pay for the bill. In the instance of the paid tips, the female median is in the case lunches higher.

# %% [markdown]
# _The same plots drawn for the group of non-smokers._

# %%
sns.catplot(x="time", y="total_bill", hue="sex", kind="box", data=nosmok)

# %%
sns.catplot(x="time", y="tip", hue="sex", kind="box", data=nosmok)

# %%
pd.pivot_table(nosmok,index=["time","sex"],values=["tip","total_bill"], aggfunc=[np.mean, np.median])
# Out:
#                    mean            median
#                     tip total_bill    tip total_bill
# time   sex
# Dinner Female  3.044138  20.004138  3.000     17.310
#        Male    3.158052  20.130130  3.000     18.290
# Lunch  Female  2.459600  15.902400  2.000     13.420
#        Male    2.941500  18.486500  2.405     16.975

# %% [markdown]
# ### Variable "TIME"

# %%
sns.pairplot(df,hue="time")

# %%
df["time"].describe()
# Out:
# count        244
# unique         2
# top       Dinner
# freq         176
# Name: time, dtype: object

# %%
pd.pivot_table(df,index=["time"],values=["tip","total_bill"], aggfunc=[np.mean, np.min,np.max,np.std])
# Out:
#             mean             amin             amax                  std  \
#              tip total_bill   tip total_bill   tip total_bill       tip
# time
# Dinner  3.102670  20.797159  1.00       3.07  10.0      50.81  1.436243
# Lunch   2.728088  17.168676  1.25       7.51   6.7      43.11  1.205345
#
#
#        total_bill
# time
# Dinner   9.142029
# Lunch    7.713882

# %% [markdown]
# Based on the above pivot table, customers spent in average more on dinners than on lunches. The tips are in line with total bills average, higher on dinners.

# %%
pd.pivot_table(df,index=["day"],values=["tip","total_bill"],columns=["time"])
# Out:
#            tip           total_bill
# time    Dinner     Lunch     Dinner      Lunch
# day
# Fri   2.940000  2.382857  19.663333  12.845714
# Sat   2.993103       NaN  20.441379        NaN
# Sun   3.255132       NaN  21.410000        NaN
# Thur  3.000000  2.767705  18.780000  17.664754

# %% [markdown]
# None lunches served on Saturdays and Sundays.

# %% [markdown]
# _To ilustrate therelationship between variables tips and total bill displayed by time and time and day when customers payed for the meal_

# %%
sns.set(style="ticks", palette="muted")
sns.relplot(x="total_bill", y="tip", 
            hue="time", style="time",
            data=df);

# %%
sns.set(style="ticks",palette="muted")
sns.relplot(x="total_bill", y="tip", col="time", hue="day",data=df)

# %% [markdown]
# The scatter plot confirms the relationship between total bill and tip. It proves that lunch was only served Thursday and Friday.

# %% [markdown]
# ### Variable "SIZE"

# %%
pd.pivot_table(df,index=["size"],values=["tip","total_bill"],aggfunc="size")
# Out:
# size
# 1      4
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# dtype: int64

# %% [markdown]
# Out of the total number of visits (244) 156 consists of group of two people.

# %%
pd.pivot_table(df,index=["size"],values=["tip","total_bill"],columns=["time"])
# Out:
#            tip           total_bill
# time    Dinner     Lunch     Dinner      Lunch
# size
# 1     1.000000  1.875000   5.160000   9.325000
# 2     2.661923  2.423077  17.228654  14.886731
# 3     3.490000  2.754000  23.997879  18.524000
# 4     4.122500  4.218000  28.404687  29.950000
# 5     3.785000  5.000000  27.287500  41.190000
# 6     5.000000  5.300000  48.170000  30.383333

# %%
pd.pivot_table(df,index=["size"],values=["tip","total_bill"],columns=["sex"],aggfunc=[np.mean,np.max,len])
# Out:
#           mean                                   amax                    \
#            tip           total_bill               tip        total_bill
# sex     Female      Male     Female       Male Female   Male     Female
# size
# 1     1.276667  1.920000   6.796667   8.580000   1.83   1.92      10.07
# 2     2.528448  2.614184  15.339483  17.104082   5.00   5.85      27.18
# 3     3.250000  3.476667  21.547143  24.287083   6.50  10.00      44.30
# 4     4.021111  4.172143  30.278889  28.078214   5.20   9.00      43.11
# 5     5.140000  3.750000  29.850000  30.122500   5.14   5.00      29.85
# 6     4.600000  5.850000  28.425000  41.235000   5.00   6.70      29.80
#
#                len
#                tip       total_bill
# sex    Male Female  Male     Female  Male
# size
# 1      8.58    3.0   1.0        3.0   1.0
# 2     40.55   58.0  98.0       58.0  98.0
# 3     50.81   14.0  24.0       14.0  24.0
# 4     48.33    9.0  28.0        9.0  28.0
# 5     41.19    1.0   4.0        1.0   4.0
# 6     48.17    2.0   2.0        2.0   2.0

# %% [markdown]
# The average tip paid by female was lower in all instances exept for the group of 5 people, when female paid higher tips. The explanation is that in the instance of the female paying for the total bill, only one group of 5 people attended and payed the tips. In the case of the males paying for the group of 5 people, the 4 meals were paid for, what has caused to smooth (average) the tips paid. We can see the dependance of the size of the group and the average tips paid. The main driver is the totall bills paid, what contributes tothat usually with the bigger group of customers the totall bill is higher.

# %%
pd.pivot_table(df,index=["size"],values=["tip","total_bill"],columns=["day"],aggfunc=[np.mean,len])
# Out:
#           mean                                                               \
#            tip                             total_bill
# day        Fri       Sat       Sun    Thur        Fri        Sat        Sun
# size
# 1     1.920000  1.000000       NaN  1.8300   8.580000   5.160000        NaN
# 2     2.644375  2.517547  2.816923  2.4425  16.321875  16.837170  17.560000
# 3     3.000000  3.797778  3.120667  2.6925  15.980000  25.509444  22.184000
# 4     4.730000  4.123846  4.087778  4.2180  40.170000  29.876154  26.688333
# 5          NaN  3.000000  4.046667  5.0000        NaN  28.150000  27.000000
# 6          NaN       NaN  5.000000  5.3000        NaN        NaN  48.170000
#
#                   len
#                   tip                   total_bill
# day        Thur   Fri   Sat   Sun  Thur        Fri   Sat   Sun  Thur
# size
# 1     10.070000   1.0   2.0   NaN   1.0        1.0   2.0   NaN   1.0
# 2     15.156875  16.0  53.0  39.0  48.0       16.0  53.0  39.0  48.0
# 3     19.160000   1.0  18.0  15.0   4.0        1.0  18.0  15.0   4.0
# 4     29.950000   1.0  13.0  18.0   5.0        1.0  13.0  18.0   5.0
# 5     41.190000   NaN   1.0   3.0   1.0        NaN   1.0   3.0   1.0
# 6     30.383333   NaN   NaN   1.0   3.0        NaN   NaN   1.0   3.0

# %% [markdown]
# Average tip and total bill displayed for the various size of the group. The dependance of tips on the total bill value is prooved again from this perspective. In general higher average tips are paid on Saturdays and Sundays, the data can be influenced by the count of occurance. The good example is the group of 4 people paying for the meal on Friday, the average tip is higher as on Saturay and Sunday. This is caused that only one group of customers attended on Friday, but 13 on Saturday and 18 on Sunday. The average tips presented on Friday is the only one tip from the group of 4, however the tips for Saturday and Sunday of the group of four are smooth by higher count of occurance.

# %% [markdown]
# ## 2, Regression analysis

# %% [markdown]
# Regression analysis is a statistical method that allows to examine the relationship between two or more variables of interest.In the analysis below the relationship between total bill paid and tips is investigated.

# %% [markdown]
# _The variable x and y are created, in variable x values from column total_bill are assigned. The variable y has assigned the values from the column tip_

# %%
x=df.loc[:,"total_bill"]

# %%
y=df.loc[:,"tip"]

# %% [markdown]
# _Scatter plot ilustrates the relationship between two variables._

# %%
plt.scatter(x,y)

# %% [markdown]
# sns.scatterplot(x,y)

# %% [markdown]
# ### Pearson's Correlation

# %% [markdown]
# Source: https://machinelearningmastery.com/how-to-use-correlation-to-understand-the-relationship-between-variables/

# %% [markdown]
# Correlation is a statistical technique that can show whether and how strongly pairs of variables are related.

# %% [markdown]
# _Calculate the covariance_

# %%
from numpy import cov

# %%
covariance=cov(x,y)

# %%
print(covariance)
# Out:
# [[79.25293861  8.32350163]
#  [ 8.32350163  1.91445464]]

# %% [markdown]
# Positive covariance, the variables change in the same direction.

# %% [markdown]
# _Correlation calculated by using np.corrcoef() function_

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.67573411],
#        [0.67573411, 1.        ]])

# %% [markdown]
# Positive r correlation coefficient of 0.67, both variables moves the same direction. The methodology of interpration of r coefficient suggest the large strenght of association between tips and total bills paid.
# * _source:https://statistics.laerd.com/statistical-guides/pearson-correlation-coefficient-statistical-guide.php_

# %% [markdown]
# ### Linear Regression Analyses

# %% [markdown]
# _Function np.polyfit used to calculate slope and y intercept_

# %%
np.polyfit(x,y,1)
# Out:
# array([0.10502452, 0.92026961])

# %% [markdown]
# https://stackoverflow.com/questions/19068862/how-to-overplot-a-line-on-a-scatter-plot-in-python

# %%
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.plot(x,y,".")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %% [markdown]
# In general the slope can be interpreted as ratio of change in y per change in x.Tips paid increased by €0.1050 on average for each per €1 increased total bill paid.

# %%
plt.plot(x,0.10502452*x+0.92027,"r")
plt.plot(x,y,".")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %% [markdown]
# _Calculating slope and y intercept to confirm the above calculated figures_

# %% [markdown]
# _Calculate the means_

# %%
x_avg=np.mean(x)

# %%
print(x_avg)
# Out:
# 19.785942622950824

# %%
y_avg=np.mean(y)

# %%
print(y_avg)
# Out:
# 2.9982786885245902

# %% [markdown]
# Calculate zero mean by subtracting means from x and y

# %%
x_zero=x-x_avg

# %%
y_zero=y-y_avg

# %% [markdown]
# _The best slope is found bythe below calculation_

# %%
m=np.sum(x_zero*y_zero)/np.sum(x_zero*x_zero)

# %% [markdown]
# _Y intercept calculated below_

# %%
c=y_avg-m*x_avg

# %%
print(m)
# Out:
# 0.10502451738435341

# %%
print(c)
# Out:
# 0.9202696135546722

# %% [markdown]
# The same results for slope and Y intercept by using the calculation and np.polyfit function.

# %% [markdown]
# The slope can be interpreted as ratio of change in y (dependent varaible) per change in x. Tips paid increased by €0.11 on average for each per €1 increased total bill paid. Interpretation of y intercept is not much relevant in this case, as it suggest if we pay zero for total bill, the tips paid will be €0.92.

# %% [markdown]
# ## 3, Detailed analysis of selected variable

# %% [markdown]
# ## Sex

# %%
df[df.loc[:,"sex"]=="Female"].describe()
# Out:
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000

# %% [markdown]
# _In order to better evaluate two variables-male paying for the food and female paying for the food, two sub-dataframes are created_

# %%
Female=df[df.loc[:,"sex"]=="Female"]

# %%
print(pd.DataFrame(Female))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 33        20.69  2.45  Female     No   Sat  Dinner     4
# 37        16.93  3.07  Female     No   Sat  Dinner     3
# 51        10.29  2.60  Female     No   Sun  Dinner     2
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 71        17.07  3.00  Female     No   Sat  Dinner     3
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 74        14.73  2.20  Female     No   Sat  Dinner     2
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 94        22.75  3.25  Female     No   Fri  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 157       25.00  3.75  Female     No   Sun  Dinner     4
# 158       13.39  2.61  Female     No   Sun  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
Male=df[df.loc[:,"sex"]=="Male"]

# %%
print(pd.DataFrame(Male))
# Out:
#      total_bill   tip   sex smoker   day    time  size
# 1         10.34  1.66  Male     No   Sun  Dinner     3
# 2         21.01  3.50  Male     No   Sun  Dinner     3
# 3         23.68  3.31  Male     No   Sun  Dinner     2
# 5         25.29  4.71  Male     No   Sun  Dinner     4
# 6          8.77  2.00  Male     No   Sun  Dinner     2
# 7         26.88  3.12  Male     No   Sun  Dinner     4
# 8         15.04  1.96  Male     No   Sun  Dinner     2
# 9         14.78  3.23  Male     No   Sun  Dinner     2
# 10        10.27  1.71  Male     No   Sun  Dinner     2
# 12        15.42  1.57  Male     No   Sun  Dinner     2
# 13        18.43  3.00  Male     No   Sun  Dinner     4
# 15        21.58  3.92  Male     No   Sun  Dinner     2
# 17        16.29  3.71  Male     No   Sun  Dinner     3
# 19        20.65  3.35  Male     No   Sat  Dinner     3
# 20        17.92  4.08  Male     No   Sat  Dinner     2
# 23        39.42  7.58  Male     No   Sat  Dinner     4
# 24        19.82  3.18  Male     No   Sat  Dinner     2
# 25        17.81  2.34  Male     No   Sat  Dinner     4
# 26        13.37  2.00  Male     No   Sat  Dinner     2
# 27        12.69  2.00  Male     No   Sat  Dinner     2
# 28        21.70  4.30  Male     No   Sat  Dinner     2
# 30         9.55  1.45  Male     No   Sat  Dinner     2
# 31        18.35  2.50  Male     No   Sat  Dinner     4
# 34        17.78  3.27  Male     No   Sat  Dinner     2
# 35        24.06  3.60  Male     No   Sat  Dinner     3
# 36        16.31  2.00  Male     No   Sat  Dinner     3
# 38        18.69  2.31  Male     No   Sat  Dinner     3
# 39        31.27  5.00  Male     No   Sat  Dinner     3
# 40        16.04  2.24  Male     No   Sat  Dinner     3
# 41        17.46  2.54  Male     No   Sun  Dinner     2
# ..          ...   ...   ...    ...   ...     ...   ...
# 195        7.56  1.44  Male     No  Thur   Lunch     2
# 196       10.34  2.00  Male    Yes  Thur   Lunch     2
# 199       13.51  2.00  Male    Yes  Thur   Lunch     2
# 200       18.71  4.00  Male    Yes  Thur   Lunch     3
# 204       20.53  4.00  Male    Yes  Thur   Lunch     4
# 206       26.59  3.41  Male    Yes   Sat  Dinner     3
# 207       38.73  3.00  Male    Yes   Sat  Dinner     4
# 208       24.27  2.03  Male    Yes   Sat  Dinner     2
# 210       30.06  2.00  Male    Yes   Sat  Dinner     3
# 211       25.89  5.16  Male    Yes   Sat  Dinner     4
# 212       48.33  9.00  Male     No   Sat  Dinner     4
# 216       28.15  3.00  Male    Yes   Sat  Dinner     5
# 217       11.59  1.50  Male    Yes   Sat  Dinner     2
# 218        7.74  1.44  Male    Yes   Sat  Dinner     2
# 220       12.16  2.20  Male    Yes   Fri   Lunch     2
# 222        8.58  1.92  Male    Yes   Fri   Lunch     1
# 224       13.42  1.58  Male    Yes   Fri   Lunch     2
# 227       20.45  3.00  Male     No   Sat  Dinner     4
# 228       13.28  2.72  Male     No   Sat  Dinner     2
# 230       24.01  2.00  Male    Yes   Sat  Dinner     4
# 231       15.69  3.00  Male    Yes   Sat  Dinner     3
# 232       11.61  3.39  Male     No   Sat  Dinner     2
# 233       10.77  1.47  Male     No   Sat  Dinner     2
# 234       15.53  3.00  Male    Yes   Sat  Dinner     2
# 235       10.07  1.25  Male     No   Sat  Dinner     2
# 236       12.60  1.00  Male    Yes   Sat  Dinner     2
# 237       32.83  1.17  Male    Yes   Sat  Dinner     2
# 239       29.03  5.92  Male     No   Sat  Dinner     3
# 241       22.67  2.00  Male    Yes   Sat  Dinner     2
# 242       17.82  1.75  Male     No   Sat  Dinner     2
#
# [157 rows x 7 columns]

# %% [markdown]
# #### By variable "Time"

# %%
pd.pivot_table(Female,index=["time"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#             mean             amax             amin                  std  \
#              tip total_bill   tip total_bill   tip total_bill       tip
# time
# Dinner  3.002115  19.213077  6.50      44.30  1.00       3.07  1.193483
# Lunch   2.582857  16.339143  5.17      43.11  1.25       8.35  1.075108
#
#                     len
#        total_bill   tip total_bill
# time
# Dinner   8.202085  52.0       52.0
# Lunch    7.500803  35.0       35.0

# %%
pd.pivot_table(Male,index=["time"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#             mean             amax             amin                  std  \
#              tip total_bill   tip total_bill   tip total_bill       tip
# time
# Dinner  3.144839  21.461452  10.0      50.81  1.00       7.25  1.529116
# Lunch   2.882121  18.048485   6.7      41.19  1.44       7.51  1.329017
#
#                      len
#        total_bill    tip total_bill
# time
# Dinner   9.460974  124.0      124.0
# Lunch    7.953435   33.0       33.0

# %% [markdown]
# As mentioned in the first part, in the section "Variable Sex", male paying for the bill pay in averge higher tips. The intresting fact is,even the ratio of paying female to male in total is 87 to 157, looking into this ratio in further details, just for lunches the ratio is 33 female to 35 males. The same ratio just for dinners represents the real difference and indicate that for the dinners only 52 females paid for the meal comparing to 124 males. The reason behinde this might be that the lunch might be more interpreted as part of working relationship, but the evening meals might represents more socializing ("dating") events.

# %%
sns.set(style="ticks",palette="muted")
sns.relplot(x="total_bill", y="tip", col="time", hue="day",data=Female)

# %%
sns.set(style="ticks",palette="muted")
sns.relplot(x="total_bill", y="tip", col="time", hue="day",data=Male)

# %% [markdown]
# The plots above ilustrate the relatioanships of total bill paid with tips paid. It suggest the strongest correlation on male sub group, which was not proved below.

# %% [markdown]
# #### By variable "Day"

# %%
pd.pivot_table(Female,index=["day"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#           mean             amax             amin                  std  \
#            tip total_bill   tip total_bill   tip total_bill       tip
# day
# Fri   2.781111  14.145556  4.30      22.75  1.00       5.75  0.938862
# Sat   2.801786  19.680357  6.50      44.30  1.00       3.07  1.234480
# Sun   3.367222  19.872222  5.20      35.26  1.01       9.60  1.136775
# Thur  2.575625  16.715312  5.17      43.11  1.25       8.35  1.109286
#
#                   len
#      total_bill   tip total_bill
# day
# Fri    4.788547   9.0        9.0
# Sat    8.806470  28.0       28.0
# Sun    7.837513  18.0       18.0
# Thur   7.759764  32.0       32.0

# %%
pd.pivot_table(Male,index=["day"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#           mean              amax             amin                  std  \
#            tip total_bill    tip total_bill   tip total_bill       tip
# day
# Fri   2.693000  19.857000   4.73      40.17  1.50       8.58  1.136428
# Sat   3.083898  20.802542  10.00      50.81  1.00       7.74  1.791360
# Sun   3.220345  21.887241   6.50      48.17  1.32       7.25  1.271172
# Thur  2.980333  18.714667   6.70      41.19  1.44       7.51  1.353734
#
#                   len
#      total_bill   tip total_bill
# day
# Fri   10.015847  10.0       10.0
# Sat    9.836306  59.0       59.0
# Sun    9.129142  58.0       58.0
# Thur   8.019728  30.0       30.0

# %% [markdown]
# The above view on the dataframes confirms that males paid in average higher bills, which draw higher tips in average. Even the values for minimum tip and maximum tip paid by males are higher that paid by females. The standard deviations confirms higher spread of tips paid by males. The ratio of paid bills by females to males indicates the same findings as in the ratios as per meal type. Thursday and Fridays (includes the lunches and dinners) the ratio is much closer between females to males paying bills (Thursday 32 to 30, Friday 9 to 10) comparing to Saturdays and Sundays dinners (no lunch served). Ratio for Saturday shows that 28 females paid the dinner comparing to 59 males, Sunday 18 females to 58 males.

# %%
g = sns.catplot(x="tip", y="day", hue="time",
                height=4.5, aspect=4.5,
                kind="box", legend=False, data=Female);
g.add_legend(title="Meal")
g.set_axis_labels("Tip ($)", "")
g.set(xlim=(0, 10), yticklabels=["Thursday", "Friday", "Saturday", "Sunday"])
g.despine(trim=True)
g.fig.set_size_inches(10, 3.5)
g.ax.set_xticks([2, 4, 6, 8, 10, 12], minor=True);
plt.setp(g.ax.get_yticklabels(), rotation=30);

# %%
g = sns.catplot(x="tip", y="day", hue="time",
                height=4.5, aspect=4.5,
                kind="box", legend=False, data=Male);
g.add_legend(title="Meal")
g.set_axis_labels("Tip ($)", "")
g.set(xlim=(0, 10), yticklabels=["Thursday", "Friday", "Saturday", "Sunday"])
g.despine(trim=True)
g.fig.set_size_inches(10, 3.5)
g.ax.set_xticks([2, 4, 6, 8, 10, 12], minor=True);
plt.setp(g.ax.get_yticklabels(), rotation=30);

# %% [markdown]
# #### By variable "Size"

# %%
pd.pivot_table(Female,index=["size"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#           mean             amax             amin                  std  \
#            tip total_bill   tip total_bill   tip total_bill       tip
# size
# 1     1.276667   6.796667  1.83      10.07  1.00       3.07  0.479201
# 2     2.528448  15.339483  5.00      27.18  1.00       5.75  0.882510
# 3     3.250000  21.547143  6.50      44.30  1.36      10.33  1.291398
# 4     4.021111  30.278889  5.20      43.11  2.45      20.69  1.084924
# 5     5.140000  29.850000  5.14      29.85  5.14      29.85       NaN
# 6     4.600000  28.425000  5.00      29.80  4.20      27.05  0.565685
#
#                   len
#      total_bill   tip total_bill
# size
# 1      3.521950   3.0        3.0
# 2      4.798400  58.0       58.0
# 3      9.100667  14.0       14.0
# 4      7.257022   9.0        9.0
# 5           NaN   1.0        1.0
# 6      1.944544   2.0        2.0

# %%
pd.pivot_table(Male,index=["size"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#           mean              amax             amin                  std  \
#            tip total_bill    tip total_bill   tip total_bill       tip
# size
# 1     1.920000   8.580000   1.92       8.58  1.92       8.58       NaN
# 2     2.614184  17.104082   5.85      40.55  1.00       7.25  1.044757
# 3     3.476667  24.287083  10.00      50.81  1.66      10.34  1.714419
# 4     4.172143  28.078214   9.00      48.33  2.00      16.49  1.798484
# 5     3.750000  30.122500   5.00      41.19  2.00      20.69  1.500000
# 6     5.850000  41.235000   6.70      48.17  5.00      34.30  1.202082
#
#                   len
#      total_bill   tip total_bill
# size
# 1           NaN   1.0        1.0
# 2      6.608159  98.0       98.0
# 3      9.625980  24.0       24.0
# 4      9.054547  28.0       28.0
# 5      8.474792   4.0        4.0
# 6      9.807571   2.0        2.0

# %% [markdown]
# Based on the size of the group, the group of two is most represented, followed by group of 3 people nad 4 people. The ratio of female paying for group of two is 58 compared to 98 males. The interesting results for group of four represents 9 females paying the final bill compared to 28 males.

# %% [markdown]
# #### By variable "Smoker"

# %%
pd.pivot_table(Female,index=["smoker"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#             mean            amax            amin                  std  \
#              tip total_bill  tip total_bill  tip total_bill       tip
# smoker
# No      2.773519  18.105185  5.2      35.83  1.0       7.25  1.128425
# Yes     2.931515  17.977879  6.5      44.30  1.0       3.07  1.219916
#
#                     len
#        total_bill   tip total_bill
# smoker
# No       7.286455  54.0       54.0
# Yes      9.189751  33.0       33.0

# %%
pd.pivot_table(Male,index=["smoker"],values=["tip","total_bill"],aggfunc=[np.mean, np.max, np.min, np.std, len])
# Out:
#             mean             amax             amin                  std  \
#              tip total_bill   tip total_bill   tip total_bill       tip
# smoker
# No      3.113402  19.791237   9.0      48.33  1.25       7.51  1.489559
# Yes     3.051167  22.284500  10.0      50.81  1.00       7.25  1.500120
#
#                     len
#        total_bill   tip total_bill
# smoker
# No       8.726566  97.0       97.0
# Yes      9.911845  60.0       60.0

# %% [markdown]
# If in the group was a smoker, the average tip paid by males was higher than the average tips paid by female. Intrestingly, the average tips paid by group of nonsmokers was higher by females than by the males group. This might be driven by in average higher total bills paid by female in non smoker group than males in non smoker group.

# %% [markdown]
# #### Regression analyses

# %% [markdown]
# _In order to investigate how are the tips depends on the total bill paid by male respectively female subcategory,  the best fit regression line was found_

# %%
xm=Male.loc[:,"total_bill"]

# %%
ym=Male.loc[:,"tip"]

# %%
np.polyfit(xm,ym,1)
# Out:
# array([0.10786068, 0.85214769])

# %%
plt.plot(np.unique(xm), np.poly1d(np.polyfit(xm, ym, 1))(np.unique(xm)))
plt.plot(xm,ym,".")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %%
xf=Female.loc[:,"total_bill"]

# %%
yf=Female.loc[:,"tip"]

# %%
np.polyfit(xf,yf,1)
# Out:
# array([0.09887792, 1.0480199 ])

# %%
plt.plot(np.unique(xf), np.poly1d(np.polyfit(xf, yf, 1))(np.unique(xf)))
plt.plot(xf,yf,".")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %% [markdown]
# In general the slope can be interpreted as ratio of change in y per change in x.Tips paid by female increased by €0.9889 on average for each per €1 increased total bill paid. Comparing to slope calculated for the tips paid by males, tips paid by males increased by €0.1078 on average for each per €1 increased total bill paid by males. As mentioned in the first part, in section "Variable Sex" male paying for the bill pay higher tips. The above calculation of slove can prove the same.

# %%
np.corrcoef(xf,yf)
# Out:
# array([[1.        , 0.68299929],
#        [0.68299929, 1.        ]])

# %%
np.corrcoef(xm,ym)
# Out:
# array([[1.        , 0.66975299],
#        [0.66975299, 1.        ]])

# %% [markdown]
# The Pearson correlation coeficient calculated for female sub-group and male-subgroup. Both of them suggest the strong correlation between two variables, even I was expecting higher value of coeficient for male group.
